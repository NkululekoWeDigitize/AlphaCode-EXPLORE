# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/malerato/Downloads/EDA/football_players.csv");
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 0  Cristiano Ronaldo   32    Portugal       94       89         63
# 1           L. Messi   30   Argentina       93       92         48
# 2             Neymar   25      Brazil       92       94         56
# 3          L. Suárez   30     Uruguay       92       88         78
# 4           M. Neuer   31     Germany       92       58         29
#
#   Agility Balance Ball control Composure         ...         Short passing  \
# 0  89      63           93        95             ...                83
# 1  90      95           95        96             ...                88
# 2  96      82           95        92             ...                81
# 3  86      60           91        83             ...                83
# 4  52      35           48        70             ...                55
#
#   Shot power Sliding tackle Sprint speed Stamina Standing tackle Strength  \
# ...

# %%
df[df.Age == df.Age.max()]
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 17977  B. Richardson   47     England       46       25         44
#
#       Agility Balance Ball control Composure         ...          \
# 17977  35      44           22        44             ...
#
#       Short passing Shot power Sliding tackle Sprint speed Stamina  \
# 17977        12         13             13           25      32
#
#       Standing tackle Strength  Vision Volleys Preferred Positions
# 17977          12       47      17      12                     GK
#
# [1 rows x 39 columns]

# %%
df[df.Overall == df.Overall.max()]
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 0  Cristiano Ronaldo   32    Portugal       94       89         63
#
#   Agility Balance Ball control Composure         ...         Short passing  \
# 0  89      63           93        95             ...                83
#
#   Shot power Sliding tackle Sprint speed Stamina Standing tackle Strength  \
# 0     94             23           91      92              31       80
#
#    Vision Volleys Preferred Positions
# 0  85      88                  ST LW
#
# [1 rows x 39 columns]

# %%
# %matplotlib inline

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D78F8BFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020D792A4358>]], dtype=object)

# %%
df.Acceleration = pd.to_numeric(df.Acceleration ,errors = "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 39 columns):
# Name                   17981 non-null object
# Age                    17981 non-null int64
# Nationality            17981 non-null object
# Overall                17981 non-null int64
# Acceleration           17926 non-null float64
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# Composure              17981 non-null object
# Crossing               17981 non-null object
# Curve                  17981 non-null object
# Dribbling              17981 non-null object
# Finishing              17981 non-null object
# Free kick accuracy     17981 non-null object
# GK diving              17981 non-null object
# GK handling            17981 non-null object
# GK kicking             17981 non-null object
# ...

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D798D04A8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020D7A343518>]], dtype=object)

# %%
df.head(100)
# Out:
#                  Name  Age         Nationality  Overall  Acceleration  \
# 0   Cristiano Ronaldo   32            Portugal       94          89.0
# 1            L. Messi   30           Argentina       93          92.0
# 2              Neymar   25              Brazil       92          94.0
# 3           L. Suárez   30             Uruguay       92          88.0
# 4            M. Neuer   31             Germany       92          58.0
# 5      R. Lewandowski   28              Poland       91          79.0
# 6              De Gea   26               Spain       90          57.0
# 7           E. Hazard   26             Belgium       90          93.0
# 8            T. Kroos   27             Germany       90          60.0
# 9          G. Higuaín   29           Argentina       90          78.0
# 10       Sergio Ramos   31               Spain       90          75.0
# 11       K. De Bruyne   26             Belgium       89          76.0
# ...

# %%
df_filtered = df[df.Acceleration<=50]

# %%
df_filtered.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D7A3FC4E0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020D7A4A9438>]], dtype=object)

# %%
df_filtered.groupby("Age").mean().reset_index().plot.scatter("Age","Acceleration")

# %%
df_filtered.groupby("Age").mean().reset_index().plot.scatter("Age","Acceleration")

# %%
df.plot(color = 'red')

# %%
import matplotlib.pyplot as plt

# %%
df_filtered.groupby("Age").mean().reset_index().plot.scatter("Age","Acceleration")

# %%
# !pip install pandas profiling
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/46/0e/6a58c06479b458a043a8ca217096328218606d9f2f84ae4ce58c67ca70fb/profiling-0.1.3.tar.gz
# ...
#   Running setup.py bdist_wheel for profiling: started
#   Running setup.py bdist_wheel for profiling: finished with status 'error'
#   Complete output from command C:\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\malerato\\AppData\\Local\\Temp\\pip-build-zjfmwup2\\profiling\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\malerato\AppData\Local\Temp\tmpb30lmz38pip-wheel- --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.6
#   creating build\lib.win-amd64-3.6\profiling
#   copying profiling\profiler.py -> build\lib.win-amd64-3.6\profiling
#   copying profiling\sortkeys.py -> build\lib.win-amd64-3.6\profiling
# ...

# %%
pandas_profiling.ProfileReport(df_filtered[["Age","Ball control","Shot power","Short passing"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-02fb2695b531> in <module>()
# ----> 1 pandas_profiling.ProfileReport(df_filtered[["Age","Ball control","Shot power","Short passing"]])
#
# NameError: name 'pandas_profiling' is not defined
